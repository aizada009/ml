# %%
#importing libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#reading data 
dataset = pd.read_csv('dataset.csv')
print(dataset.shape)
dataset.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %% [markdown]
# ![1*O2xXpYS7A3VlLXqT6SNMLg.png](attachment:1*O2xXpYS7A3VlLXqT6SNMLg.png)

# %%
#initializing our inputs and outputs
X = dataset['Head Size(cm^3)'].values
Y = dataset['Brain Weight(grams)'].values

#mean of our inputs and outputs
x_mean = np.mean(X)
y_mean = np.mean(Y)

#total number of values
n = len(X)

#using the formula to calculate the b1 and b0
numerator = 0
denominator = 0
for i in range(n):
    numerator += (X[i] - x_mean) * (Y[i] - y_mean)
    denominator += (X[i] - x_mean) ** 2
    
b1 = numerator / denominator
b0 = y_mean - (b1 * x_mean)

#printing the coefficient
print(b1, b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %%
#plotting values 
x_max = np.max(X) + 100
x_min = np.min(X) - 100

#calculating line values of x and y
x = np.linspace(x_min, x_max, 1000)
y = b0 + b1 * x

#plotting line 
plt.plot(x, y, color='#0000ff', label='Linear Regression')

#plot the data point
plt.scatter(X, Y, color='#00ff00', label='Data Point')

# x-axis label
plt.xlabel('Head Size (cm^3)')

#y-axis label
plt.ylabel('Brain Weight (grams)')

plt.legend()
plt.show()

# %% [markdown]
# ![1*SGBsn7WytmYYbuTgDatIpw.gif](attachment:1*SGBsn7WytmYYbuTgDatIpw.gif)

# %%
rmse = 0
for i in range(n):
    y_pred=  b0 + b1* X[i]
    rmse += (Y[i] - y_pred) ** 2
    
rmse = np.sqrt(rmse/n)

print(rmse)
# Out:
# 72.1206213783709

# %% [markdown]
# ![1*eebOVNcNlkwqM-fWjzmOLg.gif](attachment:1*eebOVNcNlkwqM-fWjzmOLg.gif)

# %%
sumofsquares = 0
sumofresiduals = 0

for i in range(n) :
    y_pred = b0 + b1 * X[i]
    sumofsquares += (Y[i] - y_mean) ** 2
    sumofresiduals += (Y[i] - y_pred) **2
    
score  = 1 - (sumofresiduals/sumofsquares)

print(score)
# Out:
# 0.6393117199570003
