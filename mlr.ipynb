# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('50_Startups.csv')
print(data.shape)
rd = data['R&D Spend'].values
ad = data['Administration'].values
y = data.iloc[:, 4]
data.head()
#read csv file and dividing into depended and indepeded variables
# Out:
# (50, 5)
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(rd, ad, y, color='#ef1234')
plt.show()

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
ones = np.ones(shape=(50,1))
x =np.concatenate((ones, X), axis=1)
x
# Out:
# array([[1.0000000e+00, 1.6534920e+05, 1.3689780e+05],
#        [1.0000000e+00, 1.6259770e+05, 1.5137759e+05],
#        [1.0000000e+00, 1.5344151e+05, 1.0114555e+05],
#        [1.0000000e+00, 1.4437241e+05, 1.1867185e+05],
#        [1.0000000e+00, 1.4210734e+05, 9.1391770e+04],
#        [1.0000000e+00, 1.3187690e+05, 9.9814710e+04],
#        [1.0000000e+00, 1.3461546e+05, 1.4719887e+05],
#        [1.0000000e+00, 1.3029813e+05, 1.4553006e+05],
#        [1.0000000e+00, 1.2054252e+05, 1.4871895e+05],
#        [1.0000000e+00, 1.2333488e+05, 1.0867917e+05],
#        [1.0000000e+00, 1.0191308e+05, 1.1059411e+05],
#        [1.0000000e+00, 1.0067196e+05, 9.1790610e+04],
#        [1.0000000e+00, 9.3863750e+04, 1.2732038e+05],
#        [1.0000000e+00, 9.1992390e+04, 1.3549507e+05],
#        [1.0000000e+00, 1.1994324e+05, 1.5654742e+05],
#        [1.0000000e+00, 1.1452361e+05, 1.2261684e+05],
#        [1.0000000e+00, 7.8013110e+04, 1.2159755e+05],
# ...

# %%
xt= np.transpose(x)
xt
# Out:
# array([[1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#         1.0000000e+00, 1.0000000e+00],
#        [1.6534920e+05, 1.6259770e+05, 1.5344151e+05, 1.4437241e+05,
# ...

# %%
val1= np.linalg.inv(np.dot(np.transpose(x), x))
val1
# Out:
# array([[ 4.09557623e-01, -2.63585680e-07, -3.05020198e-06],
#        [-2.63585680e-07,  1.02880971e-11, -4.07821445e-12],
#        [-3.05020198e-06, -4.07821445e-12,  2.76143598e-11]])

# %%
val2= np.dot(np.transpose(x),y)
val2
# Out:
# array([5.60063196e+06, 5.01087958e+11, 6.90713366e+11])

# %%
val3=np.dot(val1, val2)
val3
# Out:
# array([ 5.48866206e+04,  8.62117978e-01, -5.29954319e-02])

# %%
r = len(rd)
x0 = np.ones(r)
X = np.array([x0, rd, ad]).T

Y=np.array(y)
def rmse(Y, Y_pred):
    rmse = np.sqrt(sum((Y - Y_pred) ** 2) / len(Y))
    return rmse

# Model Evaluation - R2 Score
def r2_score(Y, Y_pred):
    mean_y = np.mean(Y)
    ss_tot = sum((Y - mean_y) ** 2)
    ss_res = sum((Y - Y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

Y_pred = X.dot(val3)

print(rmse(Y, Y_pred))
print(r2_score(Y, Y_pred))
# Out:
# 9115.197927536368
# 0.9478129385009173

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = np.array([rd, ad]).T
Y = np.array(y)

reg = LinearRegression()

reg = reg.fit(X, Y)

Y_pred = reg.predict(X)

rmse = np.sqrt(mean_squared_error(Y, Y_pred))
r2 = reg.score(X, Y)

print(rmse)
print(r2)
# Out:
# 9115.19792753637
# 0.9478129385009174
